# %%
import statsmodels.formula.api as smf
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve, auc
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# sklearn has 100s of models - grouped in sublibraries, such as linear_model
from sklearn.linear_model import LogisticRegression, LinearRegression

# sklearn has many tools for cleaning/processing data, also grouped in sublibraries
# splitting one dataset into train and test, computing cross validation score, cross validated prediction
from sklearn.model_selection import train_test_split, cross_val_predict, cross_val_score

#sklearn modules for computing the performance metrics
from sklearn.metrics import accuracy_score, mean_absolute_error, mean_squared_error, r2_score, \
roc_curve, auc, precision_score, recall_score, confusion_matrix

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score,train_test_split
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeRegressor,DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, ParameterGrid, StratifiedKFold, RandomizedSearchCV
from sklearn.ensemble import VotingRegressor, VotingClassifier, StackingRegressor, StackingClassifier, GradientBoostingRegressor,GradientBoostingClassifier, BaggingRegressor,BaggingClassifier,RandomForestRegressor,RandomForestClassifier,AdaBoostRegressor,AdaBoostClassifier
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import roc_curve, precision_recall_curve, auc, make_scorer, recall_score, \
accuracy_score, precision_score, confusion_matrix, mean_squared_error, r2_score

import itertools as it

#Libraries for visualizing trees
from sklearn.tree import export_graphviz 
from six import StringIO
from IPython.display import Image  
import pydotplus
import time as time

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score,train_test_split, KFold, cross_val_predict
from sklearn.metrics import mean_squared_error,r2_score,roc_curve,auc,precision_recall_curve, accuracy_score, \
recall_score, precision_score, confusion_matrix
from sklearn.tree import DecisionTreeRegressor,DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, ParameterGrid, StratifiedKFold
from sklearn.ensemble import BaggingRegressor,BaggingClassifier,AdaBoostRegressor,AdaBoostClassifier
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
import itertools as it
import time as time

import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from patsy import dmatrix
from sklearn.model_selection import cross_val_score,train_test_split, cross_val_predict
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV, ParameterGrid
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingRegressor,BaggingClassifier,RandomForestRegressor,RandomForestClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import roc_curve, precision_recall_curve, auc, make_scorer, recall_score, \
accuracy_score, precision_score, confusion_matrix, mean_squared_error, r2_score
#from pyearth import Earth
from sklearn.linear_model import LinearRegression,LogisticRegression

import itertools as it

#Libraries for visualizing trees
from sklearn.tree import export_graphviz 
from six import StringIO
from IPython.display import Image  
import pydotplus
import time as tm

#Library to compute pair-wise Euclidean distance between all observations in the data
from sklearn import metrics

#Library to impute missing values with the KNN algorithm
from sklearn import impute

from sklearn.impute import KNNImputer
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score

import warnings
with warnings.catch_warnings():
    warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from patsy import dmatrix
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import cross_val_predict, cross_val_score,train_test_split 
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import KFold
from mpl_toolkits import mplot3d
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, mean_absolute_error, mean_squared_error, r2_score, \
roc_curve, auc, precision_score, recall_score, confusion_matrix, precision_recall_curve
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, ParameterGrid, StratifiedKFold
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor, RandomForestClassifier, GradientBoostingClassifier
import plotly.express as px
from sklearn.impute import KNNImputer
import xgboost as xgb

from sklearn.ensemble import VotingRegressor, VotingClassifier, StackingRegressor, StackingClassifier, GradientBoostingRegressor,GradientBoostingClassifier, BaggingRegressor,BaggingClassifier,RandomForestRegressor,RandomForestClassifier,AdaBoostRegressor,AdaBoostClassifier

# %%
from pyearth import Earth

# %%
from catboost import CatBoostClassifier

# %%
df = pd.read_csv("water_potability.csv")
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
imputer = KNNImputer(n_neighbors=5)
imp = imputer.fit_transform(df)
df = pd.DataFrame(imp, columns = df.columns)

# %%
# Separating the predictors and response - THIS IS HOW ALL SKLEARN OBJECTS ACCEPT DATA (different from statsmodels)
y = df.Potability
X = df.drop("Potability", axis = 1)

y_copy= y.copy()
X_copy= X.copy()

# %%
# Creating training and test data
    # 80-20 split, which is usual - 70-30 split is also fine, 90-10 is fine if the dataset is large
    # random_state to set a random seed for the splitting - reproducible results
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 45)

# %%
# With linear/logistic regression in scikit-learn, especially when the predictors have different orders 
# of magn., scaling is necessary. This is to enable the training algo. which we did not cover. (Gradient Descent)
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test) # Do NOT refit the scaler with the test data, just transform it.

# %%
X_train_og = X_train.copy()
X_test_og = X_test.copy()

X_train = X_train_scaled
X_test = X_test_scaled

# %% [markdown]
# # AdaBoost Model

# %%
model_Ada = AdaBoostClassifier(random_state=1,estimator = DecisionTreeClassifier(max_depth=15),learning_rate=0.01,
                          n_estimators=2000).fit(X_train,y_train)

# %% [markdown]
# ### XGB

# %%
model_XGB = xgb.XGBClassifier(objective = 'binary:logistic',random_state=1,gamma=1,learning_rate = .001,max_depth=8,
                              n_estimators = 100,reg_lambda = 1,scale_pos_weight=1.589, subsample = 0.5, colsample_by_tree = 0.25, n_jobs = -1)
model_XGB.fit(X_train,y_train)
# Out:
# [23:01:46] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_by_tree" } are not used.
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_by_tree=0.25, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=1, gpu_id=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.001, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=-1, num_parallel_tree=None,
#               predictor=None, ...)

# %% [markdown]
# ### Random Forest Model Tuning

# %%
model_randomForest = RandomForestClassifier(random_state=1, max_features=4, n_estimators = 100, 
                               oob_score=True, max_depth =12, max_leaf_nodes = 36).fit(X_train, y_train)

# %% [markdown]
# ### Bagged Decision Tree

# %%
model_BaggedTree = BaggingClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=150, random_state=1,
                        n_jobs=-1).fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(

# %% [markdown]
# ### Gradient Boosting

# %%
model_GradBoost = GradientBoostingClassifier(random_state=1,max_depth=7,learning_rate=0.005,subsample=0.65,
                          n_estimators=60, max_features=3).fit(X_train,y_train)

# %% [markdown]
# ### CatBoost

# %%
model_cat = CatBoostClassifier().fit(X_train, y_train)
# Out:
# Learning rate set to 0.015543
# 0:	learn: 0.6911611	total: 50.9ms	remaining: 50.9s
# 1:	learn: 0.6897828	total: 54ms	remaining: 26.9s
# 2:	learn: 0.6880859	total: 59.3ms	remaining: 19.7s
# 3:	learn: 0.6865630	total: 67.2ms	remaining: 16.7s
# 4:	learn: 0.6848986	total: 70.1ms	remaining: 13.9s
# 5:	learn: 0.6831306	total: 79.7ms	remaining: 13.2s
# 6:	learn: 0.6811985	total: 82.5ms	remaining: 11.7s
# 7:	learn: 0.6800232	total: 87.9ms	remaining: 10.9s
# 8:	learn: 0.6786098	total: 92.9ms	remaining: 10.2s
# 9:	learn: 0.6767900	total: 95.8ms	remaining: 9.48s
# 10:	learn: 0.6749161	total: 101ms	remaining: 9.09s
# 11:	learn: 0.6735720	total: 116ms	remaining: 9.53s
# 12:	learn: 0.6718744	total: 118ms	remaining: 8.98s
# 13:	learn: 0.6708477	total: 121ms	remaining: 8.5s
# 14:	learn: 0.6696297	total: 123ms	remaining: 8.08s
# 15:	learn: 0.6677814	total: 125ms	remaining: 7.71s
# 16:	learn: 0.6665273	total: 128ms	remaining: 7.39s
# 17:	learn: 0.6649210	total: 130ms	remaining: 7.1s
# 18:	learn: 0.6636335	total: 132ms	remaining: 6.83s
# 19:	learn: 0.6625268	total: 135ms	remaining: 6.6s
# 20:	learn: 0.6613563	total: 137ms	remaining: 6.39s
# 21:	learn: 0.6602532	total: 139ms	remaining: 6.2s
# 22:	learn: 0.6593149	total: 142ms	remaining: 6.02s
# 23:	learn: 0.6577274	total: 144ms	remaining: 5.86s
# 24:	learn: 0.6564072	total: 146ms	remaining: 5.71s
# 25:	learn: 0.6554793	total: 149ms	remaining: 5.57s
# 26:	learn: 0.6540216	total: 151ms	remaining: 5.44s
# 27:	learn: 0.6526070	total: 153ms	remaining: 5.32s
# 28:	learn: 0.6515864	total: 156ms	remaining: 5.21s
# 29:	learn: 0.6506660	total: 158ms	remaining: 5.11s
# 30:	learn: 0.6494609	total: 160ms	remaining: 5.01s
# 31:	learn: 0.6487073	total: 163ms	remaining: 4.92s
# 32:	learn: 0.6478750	total: 165ms	remaining: 4.83s
# 33:	learn: 0.6464604	total: 167ms	remaining: 4.75s
# 34:	learn: 0.6453777	total: 170ms	remaining: 4.7s
# 35:	learn: 0.6446369	total: 173ms	remaining: 4.64s
# 36:	learn: 0.6433927	total: 176ms	remaining: 4.58s
# 37:	learn: 0.6424068	total: 178ms	remaining: 4.51s
# 38:	learn: 0.6413655	total: 181ms	remaining: 4.45s
# 39:	learn: 0.6407574	total: 185ms	remaining: 4.43s
# 40:	learn: 0.6400833	total: 187ms	remaining: 4.38s
# 41:	learn: 0.6389345	total: 190ms	remaining: 4.33s
# 42:	learn: 0.6379969	total: 192ms	remaining: 4.28s
# 43:	learn: 0.6370255	total: 195ms	remaining: 4.24s
# 44:	learn: 0.6359900	total: 198ms	remaining: 4.21s
# 45:	learn: 0.6349277	total: 201ms	remaining: 4.17s
# 46:	learn: 0.6340836	total: 203ms	remaining: 4.12s
# 47:	learn: 0.6334074	total: 206ms	remaining: 4.08s
# 48:	learn: 0.6325913	total: 208ms	remaining: 4.03s
# 49:	learn: 0.6315372	total: 210ms	remaining: 3.99s
# 50:	learn: 0.6304620	total: 212ms	remaining: 3.95s
# 51:	learn: 0.6293902	total: 215ms	remaining: 3.91s
# 52:	learn: 0.6284005	total: 217ms	remaining: 3.88s
# 53:	learn: 0.6276609	total: 219ms	remaining: 3.84s
# 54:	learn: 0.6268538	total: 222ms	remaining: 3.81s
# 55:	learn: 0.6263253	total: 224ms	remaining: 3.78s
# 56:	learn: 0.6256522	total: 227ms	remaining: 3.75s
# 57:	learn: 0.6247576	total: 229ms	remaining: 3.73s
# 58:	learn: 0.6237410	total: 232ms	remaining: 3.7s
# 59:	learn: 0.6230489	total: 234ms	remaining: 3.67s
# 60:	learn: 0.6223742	total: 237ms	remaining: 3.65s
# 61:	learn: 0.6217025	total: 239ms	remaining: 3.62s
# 62:	learn: 0.6206641	total: 242ms	remaining: 3.59s
# 63:	learn: 0.6202072	total: 244ms	remaining: 3.57s
# 64:	learn: 0.6196601	total: 246ms	remaining: 3.54s
# 65:	learn: 0.6190141	total: 248ms	remaining: 3.51s
# 66:	learn: 0.6183049	total: 251ms	remaining: 3.49s
# 67:	learn: 0.6172375	total: 253ms	remaining: 3.47s
# 68:	learn: 0.6163836	total: 256ms	remaining: 3.45s
# 69:	learn: 0.6158870	total: 258ms	remaining: 3.43s
# 70:	learn: 0.6153099	total: 261ms	remaining: 3.41s
# 71:	learn: 0.6144326	total: 263ms	remaining: 3.39s
# 72:	learn: 0.6139586	total: 265ms	remaining: 3.37s
# 73:	learn: 0.6136255	total: 268ms	remaining: 3.35s
# 74:	learn: 0.6129532	total: 270ms	remaining: 3.33s
# 75:	learn: 0.6125160	total: 272ms	remaining: 3.31s
# 76:	learn: 0.6121052	total: 275ms	remaining: 3.29s
# 77:	learn: 0.6113976	total: 277ms	remaining: 3.27s
# 78:	learn: 0.6104724	total: 279ms	remaining: 3.26s
# 79:	learn: 0.6097543	total: 282ms	remaining: 3.24s
# 80:	learn: 0.6093158	total: 284ms	remaining: 3.22s
# 81:	learn: 0.6084009	total: 286ms	remaining: 3.21s
# 82:	learn: 0.6077952	total: 289ms	remaining: 3.19s
# 83:	learn: 0.6073073	total: 291ms	remaining: 3.17s
# 84:	learn: 0.6069185	total: 294ms	remaining: 3.16s
# 85:	learn: 0.6060665	total: 296ms	remaining: 3.14s
# 86:	learn: 0.6056513	total: 298ms	remaining: 3.13s
# 87:	learn: 0.6052476	total: 301ms	remaining: 3.12s
# 88:	learn: 0.6048182	total: 303ms	remaining: 3.1s
# 89:	learn: 0.6042400	total: 306ms	remaining: 3.09s
# 90:	learn: 0.6037328	total: 308ms	remaining: 3.08s
# 91:	learn: 0.6033201	total: 311ms	remaining: 3.06s
# 92:	learn: 0.6026023	total: 313ms	remaining: 3.05s
# 93:	learn: 0.6020269	total: 315ms	remaining: 3.04s
# 94:	learn: 0.6014444	total: 318ms	remaining: 3.03s
# 95:	learn: 0.6007105	total: 320ms	remaining: 3.01s
# 96:	learn: 0.6002155	total: 322ms	remaining: 3s
# 97:	learn: 0.5996023	total: 325ms	remaining: 2.99s
# 98:	learn: 0.5992803	total: 327ms	remaining: 2.98s
# 99:	learn: 0.5985851	total: 330ms	remaining: 2.97s
# 100:	learn: 0.5979662	total: 332ms	remaining: 2.96s
# 101:	learn: 0.5971837	total: 335ms	remaining: 2.95s
# 102:	learn: 0.5967122	total: 337ms	remaining: 2.94s
# 103:	learn: 0.5959694	total: 340ms	remaining: 2.93s
# 104:	learn: 0.5956365	total: 344ms	remaining: 2.93s
# 105:	learn: 0.5950686	total: 347ms	remaining: 2.92s
# 106:	learn: 0.5946849	total: 349ms	remaining: 2.92s
# 107:	learn: 0.5942944	total: 352ms	remaining: 2.91s
# 108:	learn: 0.5939734	total: 356ms	remaining: 2.91s
# 109:	learn: 0.5934043	total: 359ms	remaining: 2.9s
# 110:	learn: 0.5929565	total: 362ms	remaining: 2.9s
# 111:	learn: 0.5924231	total: 366ms	remaining: 2.9s
# 112:	learn: 0.5920252	total: 369ms	remaining: 2.9s
# 113:	learn: 0.5914623	total: 372ms	remaining: 2.89s
# 114:	learn: 0.5910269	total: 374ms	remaining: 2.88s
# 115:	learn: 0.5905283	total: 376ms	remaining: 2.87s
# 116:	learn: 0.5900898	total: 379ms	remaining: 2.86s
# 117:	learn: 0.5898465	total: 381ms	remaining: 2.85s
# 118:	learn: 0.5892755	total: 383ms	remaining: 2.84s
# 119:	learn: 0.5886704	total: 386ms	remaining: 2.83s
# 120:	learn: 0.5881530	total: 388ms	remaining: 2.82s
# 121:	learn: 0.5876009	total: 392ms	remaining: 2.82s
# 122:	learn: 0.5871514	total: 396ms	remaining: 2.82s
# 123:	learn: 0.5866494	total: 398ms	remaining: 2.81s
# 124:	learn: 0.5860226	total: 401ms	remaining: 2.8s
# 125:	learn: 0.5849838	total: 403ms	remaining: 2.8s
# 126:	learn: 0.5843812	total: 406ms	remaining: 2.79s
# 127:	learn: 0.5839700	total: 408ms	remaining: 2.78s
# 128:	learn: 0.5835336	total: 410ms	remaining: 2.77s
# 129:	learn: 0.5831674	total: 413ms	remaining: 2.76s
# 130:	learn: 0.5828723	total: 415ms	remaining: 2.75s
# 131:	learn: 0.5823777	total: 418ms	remaining: 2.75s
# 132:	learn: 0.5821209	total: 420ms	remaining: 2.74s
# 133:	learn: 0.5815542	total: 422ms	remaining: 2.73s
# 134:	learn: 0.5811492	total: 425ms	remaining: 2.72s
# 135:	learn: 0.5807737	total: 427ms	remaining: 2.71s
# 136:	learn: 0.5805700	total: 429ms	remaining: 2.7s
# 137:	learn: 0.5801458	total: 432ms	remaining: 2.7s
# 138:	learn: 0.5796881	total: 434ms	remaining: 2.69s
# 139:	learn: 0.5793314	total: 436ms	remaining: 2.68s
# 140:	learn: 0.5790758	total: 439ms	remaining: 2.67s
# 141:	learn: 0.5786455	total: 441ms	remaining: 2.67s
# 142:	learn: 0.5781076	total: 444ms	remaining: 2.66s
# 143:	learn: 0.5776590	total: 446ms	remaining: 2.65s
# 144:	learn: 0.5772054	total: 448ms	remaining: 2.64s
# 145:	learn: 0.5767904	total: 451ms	remaining: 2.63s
# 146:	learn: 0.5765566	total: 453ms	remaining: 2.63s
# 147:	learn: 0.5759638	total: 455ms	remaining: 2.62s
# 148:	learn: 0.5755521	total: 459ms	remaining: 2.62s
# 149:	learn: 0.5750785	total: 462ms	remaining: 2.62s
# 150:	learn: 0.5745782	total: 464ms	remaining: 2.61s
# 151:	learn: 0.5742730	total: 466ms	remaining: 2.6s
# 152:	learn: 0.5736258	total: 469ms	remaining: 2.59s
# 153:	learn: 0.5731679	total: 471ms	remaining: 2.59s
# 154:	learn: 0.5726232	total: 474ms	remaining: 2.58s
# 155:	learn: 0.5723717	total: 476ms	remaining: 2.57s
# 156:	learn: 0.5719785	total: 478ms	remaining: 2.57s
# 157:	learn: 0.5715178	total: 480ms	remaining: 2.56s
# 158:	learn: 0.5708611	total: 483ms	remaining: 2.55s
# 159:	learn: 0.5704895	total: 485ms	remaining: 2.54s
# 160:	learn: 0.5701744	total: 487ms	remaining: 2.54s
# 161:	learn: 0.5699560	total: 490ms	remaining: 2.53s
# 162:	learn: 0.5695218	total: 492ms	remaining: 2.53s
# 163:	learn: 0.5690908	total: 495ms	remaining: 2.52s
# 164:	learn: 0.5685168	total: 497ms	remaining: 2.52s
# 165:	learn: 0.5681952	total: 500ms	remaining: 2.51s
# 166:	learn: 0.5679225	total: 502ms	remaining: 2.5s
# 167:	learn: 0.5676166	total: 505ms	remaining: 2.5s
# 168:	learn: 0.5670655	total: 507ms	remaining: 2.49s
# 169:	learn: 0.5667838	total: 510ms	remaining: 2.49s
# 170:	learn: 0.5662571	total: 512ms	remaining: 2.48s
# 171:	learn: 0.5657878	total: 515ms	remaining: 2.48s
# 172:	learn: 0.5653518	total: 517ms	remaining: 2.47s
# 173:	learn: 0.5650263	total: 520ms	remaining: 2.47s
# 174:	learn: 0.5644877	total: 522ms	remaining: 2.46s
# 175:	learn: 0.5640631	total: 525ms	remaining: 2.46s
# 176:	learn: 0.5639074	total: 527ms	remaining: 2.45s
# 177:	learn: 0.5636108	total: 530ms	remaining: 2.45s
# 178:	learn: 0.5631786	total: 533ms	remaining: 2.45s
# 179:	learn: 0.5627650	total: 536ms	remaining: 2.44s
# 180:	learn: 0.5623863	total: 538ms	remaining: 2.44s
# 181:	learn: 0.5621078	total: 541ms	remaining: 2.43s
# 182:	learn: 0.5616959	total: 543ms	remaining: 2.43s
# 183:	learn: 0.5614433	total: 546ms	remaining: 2.42s
# 184:	learn: 0.5609778	total: 548ms	remaining: 2.42s
# 185:	learn: 0.5606424	total: 551ms	remaining: 2.41s
# 186:	learn: 0.5603193	total: 553ms	remaining: 2.41s
# 187:	learn: 0.5600444	total: 556ms	remaining: 2.4s
# 188:	learn: 0.5597549	total: 558ms	remaining: 2.4s
# 189:	learn: 0.5594727	total: 561ms	remaining: 2.39s
# 190:	learn: 0.5592247	total: 563ms	remaining: 2.39s
# 191:	learn: 0.5587939	total: 566ms	remaining: 2.38s
# 192:	learn: 0.5583761	total: 568ms	remaining: 2.38s
# 193:	learn: 0.5579387	total: 571ms	remaining: 2.37s
# 194:	learn: 0.5576126	total: 573ms	remaining: 2.37s
# 195:	learn: 0.5573390	total: 576ms	remaining: 2.36s
# 196:	learn: 0.5568090	total: 578ms	remaining: 2.36s
# 197:	learn: 0.5564093	total: 581ms	remaining: 2.35s
# 198:	learn: 0.5562266	total: 583ms	remaining: 2.35s
# 199:	learn: 0.5560177	total: 586ms	remaining: 2.34s
# 200:	learn: 0.5555181	total: 591ms	remaining: 2.35s
# 201:	learn: 0.5554195	total: 594ms	remaining: 2.35s
# 202:	learn: 0.5550706	total: 597ms	remaining: 2.34s
# 203:	learn: 0.5546946	total: 600ms	remaining: 2.34s
# 204:	learn: 0.5543330	total: 602ms	remaining: 2.34s
# 205:	learn: 0.5541443	total: 605ms	remaining: 2.33s
# 206:	learn: 0.5538550	total: 607ms	remaining: 2.33s
# 207:	learn: 0.5534194	total: 609ms	remaining: 2.32s
# 208:	learn: 0.5532043	total: 612ms	remaining: 2.31s
# 209:	learn: 0.5529017	total: 614ms	remaining: 2.31s
# 210:	learn: 0.5523687	total: 616ms	remaining: 2.3s
# 211:	learn: 0.5521371	total: 619ms	remaining: 2.3s
# 212:	learn: 0.5517077	total: 621ms	remaining: 2.29s
# 213:	learn: 0.5513643	total: 623ms	remaining: 2.29s
# 214:	learn: 0.5508984	total: 626ms	remaining: 2.28s
# 215:	learn: 0.5506658	total: 628ms	remaining: 2.28s
# 216:	learn: 0.5503537	total: 631ms	remaining: 2.27s
# 217:	learn: 0.5500257	total: 633ms	remaining: 2.27s
# 218:	learn: 0.5497558	total: 636ms	remaining: 2.27s
# 219:	learn: 0.5493633	total: 638ms	remaining: 2.26s
# 220:	learn: 0.5491252	total: 641ms	remaining: 2.26s
# 221:	learn: 0.5487000	total: 643ms	remaining: 2.25s
# 222:	learn: 0.5484445	total: 645ms	remaining: 2.25s
# 223:	learn: 0.5481285	total: 648ms	remaining: 2.24s
# 224:	learn: 0.5479348	total: 651ms	remaining: 2.24s
# 225:	learn: 0.5476180	total: 653ms	remaining: 2.24s
# 226:	learn: 0.5473803	total: 656ms	remaining: 2.23s
# 227:	learn: 0.5470318	total: 659ms	remaining: 2.23s
# 228:	learn: 0.5466036	total: 661ms	remaining: 2.23s
# 229:	learn: 0.5461467	total: 664ms	remaining: 2.22s
# 230:	learn: 0.5459604	total: 667ms	remaining: 2.22s
# 231:	learn: 0.5453632	total: 669ms	remaining: 2.21s
# 232:	learn: 0.5451141	total: 672ms	remaining: 2.21s
# 233:	learn: 0.5448847	total: 674ms	remaining: 2.21s
# 234:	learn: 0.5443710	total: 677ms	remaining: 2.2s
# 235:	learn: 0.5441177	total: 679ms	remaining: 2.2s
# 236:	learn: 0.5438120	total: 682ms	remaining: 2.19s
# 237:	learn: 0.5435151	total: 684ms	remaining: 2.19s
# 238:	learn: 0.5429441	total: 686ms	remaining: 2.18s
# 239:	learn: 0.5425798	total: 689ms	remaining: 2.18s
# 240:	learn: 0.5422059	total: 691ms	remaining: 2.17s
# 241:	learn: 0.5419647	total: 693ms	remaining: 2.17s
# 242:	learn: 0.5415675	total: 696ms	remaining: 2.17s
# 243:	learn: 0.5412468	total: 698ms	remaining: 2.16s
# 244:	learn: 0.5409268	total: 700ms	remaining: 2.16s
# 245:	learn: 0.5405759	total: 703ms	remaining: 2.15s
# 246:	learn: 0.5404057	total: 705ms	remaining: 2.15s
# 247:	learn: 0.5401558	total: 707ms	remaining: 2.14s
# 248:	learn: 0.5399158	total: 709ms	remaining: 2.14s
# 249:	learn: 0.5395523	total: 712ms	remaining: 2.13s
# 250:	learn: 0.5392867	total: 714ms	remaining: 2.13s
# 251:	learn: 0.5391072	total: 716ms	remaining: 2.13s
# 252:	learn: 0.5389055	total: 719ms	remaining: 2.12s
# 253:	learn: 0.5385887	total: 721ms	remaining: 2.12s
# 254:	learn: 0.5381477	total: 723ms	remaining: 2.11s
# 255:	learn: 0.5379283	total: 726ms	remaining: 2.11s
# 256:	learn: 0.5377191	total: 728ms	remaining: 2.1s
# 257:	learn: 0.5374149	total: 732ms	remaining: 2.11s
# 258:	learn: 0.5369955	total: 738ms	remaining: 2.11s
# 259:	learn: 0.5367004	total: 741ms	remaining: 2.11s
# 260:	learn: 0.5364859	total: 744ms	remaining: 2.1s
# 261:	learn: 0.5361253	total: 746ms	remaining: 2.1s
# 262:	learn: 0.5359084	total: 749ms	remaining: 2.1s
# 263:	learn: 0.5356409	total: 751ms	remaining: 2.09s
# 264:	learn: 0.5354813	total: 754ms	remaining: 2.09s
# 265:	learn: 0.5352964	total: 756ms	remaining: 2.09s
# 266:	learn: 0.5352090	total: 759ms	remaining: 2.08s
# 267:	learn: 0.5350225	total: 761ms	remaining: 2.08s
# 268:	learn: 0.5347871	total: 763ms	remaining: 2.07s
# 269:	learn: 0.5344692	total: 766ms	remaining: 2.07s
# 270:	learn: 0.5341118	total: 768ms	remaining: 2.07s
# 271:	learn: 0.5338747	total: 771ms	remaining: 2.06s
# 272:	learn: 0.5335284	total: 775ms	remaining: 2.06s
# 273:	learn: 0.5332682	total: 777ms	remaining: 2.06s
# 274:	learn: 0.5330054	total: 781ms	remaining: 2.06s
# 275:	learn: 0.5327361	total: 784ms	remaining: 2.06s
# 276:	learn: 0.5324110	total: 786ms	remaining: 2.05s
# 277:	learn: 0.5322730	total: 789ms	remaining: 2.05s
# 278:	learn: 0.5321247	total: 791ms	remaining: 2.04s
# 279:	learn: 0.5318331	total: 793ms	remaining: 2.04s
# 280:	learn: 0.5316574	total: 796ms	remaining: 2.04s
# 281:	learn: 0.5314184	total: 798ms	remaining: 2.03s
# 282:	learn: 0.5311009	total: 801ms	remaining: 2.03s
# 283:	learn: 0.5305883	total: 803ms	remaining: 2.02s
# 284:	learn: 0.5302684	total: 806ms	remaining: 2.02s
# 285:	learn: 0.5299789	total: 809ms	remaining: 2.02s
# 286:	learn: 0.5297854	total: 812ms	remaining: 2.02s
# 287:	learn: 0.5294710	total: 815ms	remaining: 2.02s
# 288:	learn: 0.5292326	total: 818ms	remaining: 2.01s
# 289:	learn: 0.5287723	total: 821ms	remaining: 2.01s
# 290:	learn: 0.5285889	total: 824ms	remaining: 2.01s
# 291:	learn: 0.5284259	total: 827ms	remaining: 2s
# 292:	learn: 0.5281978	total: 830ms	remaining: 2s
# 293:	learn: 0.5278660	total: 833ms	remaining: 2s
# 294:	learn: 0.5275720	total: 835ms	remaining: 2s
# 295:	learn: 0.5272464	total: 837ms	remaining: 1.99s
# 296:	learn: 0.5269604	total: 840ms	remaining: 1.99s
# 297:	learn: 0.5267722	total: 842ms	remaining: 1.98s
# 298:	learn: 0.5265529	total: 845ms	remaining: 1.98s
# 299:	learn: 0.5262113	total: 847ms	remaining: 1.98s
# 300:	learn: 0.5259513	total: 850ms	remaining: 1.97s
# 301:	learn: 0.5257528	total: 852ms	remaining: 1.97s
# 302:	learn: 0.5256073	total: 854ms	remaining: 1.97s
# 303:	learn: 0.5254100	total: 857ms	remaining: 1.96s
# 304:	learn: 0.5247721	total: 859ms	remaining: 1.96s
# 305:	learn: 0.5243404	total: 861ms	remaining: 1.95s
# 306:	learn: 0.5239628	total: 864ms	remaining: 1.95s
# 307:	learn: 0.5236337	total: 866ms	remaining: 1.95s
# 308:	learn: 0.5233917	total: 869ms	remaining: 1.94s
# 309:	learn: 0.5231053	total: 871ms	remaining: 1.94s
# 310:	learn: 0.5228807	total: 873ms	remaining: 1.93s
# 311:	learn: 0.5226673	total: 876ms	remaining: 1.93s
# 312:	learn: 0.5224610	total: 878ms	remaining: 1.93s
# 313:	learn: 0.5222409	total: 880ms	remaining: 1.92s
# 314:	learn: 0.5220107	total: 883ms	remaining: 1.92s
# 315:	learn: 0.5217705	total: 885ms	remaining: 1.92s
# 316:	learn: 0.5214244	total: 887ms	remaining: 1.91s
# 317:	learn: 0.5211428	total: 890ms	remaining: 1.91s
# 318:	learn: 0.5207690	total: 892ms	remaining: 1.9s
# 319:	learn: 0.5204867	total: 894ms	remaining: 1.9s
# 320:	learn: 0.5201535	total: 896ms	remaining: 1.9s
# 321:	learn: 0.5197984	total: 899ms	remaining: 1.89s
# 322:	learn: 0.5194810	total: 901ms	remaining: 1.89s
# 323:	learn: 0.5191437	total: 904ms	remaining: 1.89s
# 324:	learn: 0.5188040	total: 906ms	remaining: 1.88s
# 325:	learn: 0.5186243	total: 909ms	remaining: 1.88s
# 326:	learn: 0.5183956	total: 912ms	remaining: 1.88s
# 327:	learn: 0.5180780	total: 914ms	remaining: 1.87s
# 328:	learn: 0.5178606	total: 917ms	remaining: 1.87s
# 329:	learn: 0.5174712	total: 924ms	remaining: 1.88s
# 330:	learn: 0.5172471	total: 927ms	remaining: 1.87s
# 331:	learn: 0.5171290	total: 929ms	remaining: 1.87s
# 332:	learn: 0.5167802	total: 933ms	remaining: 1.87s
# 333:	learn: 0.5165423	total: 936ms	remaining: 1.86s
# 334:	learn: 0.5161331	total: 938ms	remaining: 1.86s
# 335:	learn: 0.5157232	total: 941ms	remaining: 1.86s
# 336:	learn: 0.5154337	total: 943ms	remaining: 1.85s
# 337:	learn: 0.5151832	total: 946ms	remaining: 1.85s
# 338:	learn: 0.5148460	total: 948ms	remaining: 1.85s
# 339:	learn: 0.5146936	total: 950ms	remaining: 1.84s
# 340:	learn: 0.5142157	total: 952ms	remaining: 1.84s
# 341:	learn: 0.5140633	total: 955ms	remaining: 1.84s
# 342:	learn: 0.5138131	total: 957ms	remaining: 1.83s
# 343:	learn: 0.5134079	total: 959ms	remaining: 1.83s
# 344:	learn: 0.5132184	total: 962ms	remaining: 1.82s
# 345:	learn: 0.5130104	total: 964ms	remaining: 1.82s
# 346:	learn: 0.5128165	total: 967ms	remaining: 1.82s
# 347:	learn: 0.5125400	total: 969ms	remaining: 1.81s
# 348:	learn: 0.5123710	total: 971ms	remaining: 1.81s
# 349:	learn: 0.5121912	total: 974ms	remaining: 1.81s
# 350:	learn: 0.5119982	total: 977ms	remaining: 1.81s
# 351:	learn: 0.5118159	total: 980ms	remaining: 1.8s
# 352:	learn: 0.5116518	total: 984ms	remaining: 1.8s
# 353:	learn: 0.5113999	total: 986ms	remaining: 1.8s
# 354:	learn: 0.5111724	total: 989ms	remaining: 1.8s
# 355:	learn: 0.5108931	total: 992ms	remaining: 1.79s
# 356:	learn: 0.5104612	total: 995ms	remaining: 1.79s
# 357:	learn: 0.5102885	total: 997ms	remaining: 1.79s
# 358:	learn: 0.5100269	total: 1s	remaining: 1.78s
# 359:	learn: 0.5097295	total: 1s	remaining: 1.78s
# 360:	learn: 0.5095644	total: 1s	remaining: 1.78s
# 361:	learn: 0.5094086	total: 1.01s	remaining: 1.78s
# 362:	learn: 0.5091977	total: 1.01s	remaining: 1.77s
# 363:	learn: 0.5089554	total: 1.01s	remaining: 1.77s
# 364:	learn: 0.5087769	total: 1.01s	remaining: 1.77s
# 365:	learn: 0.5085290	total: 1.02s	remaining: 1.76s
# 366:	learn: 0.5083418	total: 1.02s	remaining: 1.76s
# 367:	learn: 0.5080355	total: 1.02s	remaining: 1.76s
# 368:	learn: 0.5077725	total: 1.03s	remaining: 1.75s
# 369:	learn: 0.5074820	total: 1.03s	remaining: 1.75s
# 370:	learn: 0.5070780	total: 1.03s	remaining: 1.75s
# 371:	learn: 0.5068370	total: 1.03s	remaining: 1.75s
# 372:	learn: 0.5065429	total: 1.04s	remaining: 1.74s
# 373:	learn: 0.5064102	total: 1.04s	remaining: 1.74s
# 374:	learn: 0.5062817	total: 1.04s	remaining: 1.74s
# 375:	learn: 0.5061229	total: 1.04s	remaining: 1.73s
# 376:	learn: 0.5060069	total: 1.05s	remaining: 1.73s
# 377:	learn: 0.5057773	total: 1.05s	remaining: 1.73s
# 378:	learn: 0.5056103	total: 1.05s	remaining: 1.72s
# 379:	learn: 0.5052999	total: 1.05s	remaining: 1.72s
# 380:	learn: 0.5049602	total: 1.06s	remaining: 1.72s
# 381:	learn: 0.5047282	total: 1.06s	remaining: 1.71s
# 382:	learn: 0.5045438	total: 1.06s	remaining: 1.71s
# 383:	learn: 0.5043529	total: 1.06s	remaining: 1.71s
# 384:	learn: 0.5041544	total: 1.07s	remaining: 1.7s
# 385:	learn: 0.5039946	total: 1.07s	remaining: 1.7s
# 386:	learn: 0.5038040	total: 1.07s	remaining: 1.7s
# 387:	learn: 0.5035146	total: 1.07s	remaining: 1.69s
# 388:	learn: 0.5032827	total: 1.08s	remaining: 1.69s
# 389:	learn: 0.5031391	total: 1.08s	remaining: 1.69s
# 390:	learn: 0.5029346	total: 1.08s	remaining: 1.68s
# 391:	learn: 0.5027058	total: 1.08s	remaining: 1.68s
# 392:	learn: 0.5024197	total: 1.09s	remaining: 1.68s
# 393:	learn: 0.5021370	total: 1.09s	remaining: 1.68s
# 394:	learn: 0.5019153	total: 1.09s	remaining: 1.67s
# 395:	learn: 0.5016996	total: 1.09s	remaining: 1.67s
# 396:	learn: 0.5014582	total: 1.1s	remaining: 1.67s
# 397:	learn: 0.5011570	total: 1.1s	remaining: 1.66s
# 398:	learn: 0.5008134	total: 1.1s	remaining: 1.66s
# 399:	learn: 0.5005222	total: 1.1s	remaining: 1.66s
# 400:	learn: 0.5001249	total: 1.11s	remaining: 1.65s
# 401:	learn: 0.4999317	total: 1.11s	remaining: 1.65s
# 402:	learn: 0.4995006	total: 1.11s	remaining: 1.65s
# 403:	learn: 0.4993207	total: 1.11s	remaining: 1.64s
# 404:	learn: 0.4990245	total: 1.12s	remaining: 1.64s
# 405:	learn: 0.4987113	total: 1.12s	remaining: 1.64s
# 406:	learn: 0.4983943	total: 1.12s	remaining: 1.63s
# 407:	learn: 0.4978596	total: 1.12s	remaining: 1.63s
# 408:	learn: 0.4976152	total: 1.13s	remaining: 1.63s
# 409:	learn: 0.4973780	total: 1.13s	remaining: 1.63s
# 410:	learn: 0.4970257	total: 1.13s	remaining: 1.62s
# 411:	learn: 0.4968040	total: 1.13s	remaining: 1.62s
# 412:	learn: 0.4965598	total: 1.14s	remaining: 1.61s
# 413:	learn: 0.4962436	total: 1.14s	remaining: 1.61s
# 414:	learn: 0.4960252	total: 1.14s	remaining: 1.61s
# 415:	learn: 0.4958779	total: 1.14s	remaining: 1.61s
# 416:	learn: 0.4957102	total: 1.15s	remaining: 1.6s
# 417:	learn: 0.4955359	total: 1.15s	remaining: 1.6s
# 418:	learn: 0.4952674	total: 1.15s	remaining: 1.6s
# 419:	learn: 0.4949216	total: 1.15s	remaining: 1.59s
# 420:	learn: 0.4946611	total: 1.16s	remaining: 1.59s
# 421:	learn: 0.4944695	total: 1.16s	remaining: 1.59s
# 422:	learn: 0.4940838	total: 1.16s	remaining: 1.58s
# 423:	learn: 0.4938788	total: 1.16s	remaining: 1.58s
# 424:	learn: 0.4936713	total: 1.17s	remaining: 1.58s
# 425:	learn: 0.4934436	total: 1.17s	remaining: 1.58s
# 426:	learn: 0.4932162	total: 1.17s	remaining: 1.57s
# 427:	learn: 0.4930096	total: 1.18s	remaining: 1.57s
# 428:	learn: 0.4927694	total: 1.18s	remaining: 1.57s
# 429:	learn: 0.4925431	total: 1.18s	remaining: 1.56s
# 430:	learn: 0.4923123	total: 1.18s	remaining: 1.56s
# 431:	learn: 0.4919306	total: 1.18s	remaining: 1.56s
# 432:	learn: 0.4916137	total: 1.19s	remaining: 1.55s
# 433:	learn: 0.4914288	total: 1.19s	remaining: 1.55s
# 434:	learn: 0.4911942	total: 1.19s	remaining: 1.55s
# 435:	learn: 0.4908304	total: 1.19s	remaining: 1.54s
# 436:	learn: 0.4906708	total: 1.2s	remaining: 1.54s
# 437:	learn: 0.4904604	total: 1.2s	remaining: 1.54s
# 438:	learn: 0.4903096	total: 1.2s	remaining: 1.53s
# 439:	learn: 0.4901751	total: 1.2s	remaining: 1.53s
# 440:	learn: 0.4899207	total: 1.21s	remaining: 1.53s
# 441:	learn: 0.4895681	total: 1.21s	remaining: 1.53s
# 442:	learn: 0.4892836	total: 1.21s	remaining: 1.52s
# 443:	learn: 0.4889626	total: 1.21s	remaining: 1.52s
# 444:	learn: 0.4888296	total: 1.22s	remaining: 1.52s
# 445:	learn: 0.4887182	total: 1.22s	remaining: 1.51s
# 446:	learn: 0.4884573	total: 1.22s	remaining: 1.51s
# 447:	learn: 0.4880865	total: 1.23s	remaining: 1.51s
# 448:	learn: 0.4878372	total: 1.23s	remaining: 1.51s
# 449:	learn: 0.4876830	total: 1.23s	remaining: 1.5s
# 450:	learn: 0.4872624	total: 1.23s	remaining: 1.5s
# 451:	learn: 0.4871088	total: 1.23s	remaining: 1.5s
# 452:	learn: 0.4868755	total: 1.24s	remaining: 1.49s
# 453:	learn: 0.4865166	total: 1.24s	remaining: 1.49s
# 454:	learn: 0.4863581	total: 1.24s	remaining: 1.49s
# 455:	learn: 0.4860571	total: 1.24s	remaining: 1.48s
# 456:	learn: 0.4858435	total: 1.25s	remaining: 1.48s
# 457:	learn: 0.4855096	total: 1.25s	remaining: 1.48s
# 458:	learn: 0.4852830	total: 1.25s	remaining: 1.47s
# 459:	learn: 0.4850596	total: 1.25s	remaining: 1.47s
# 460:	learn: 0.4846330	total: 1.26s	remaining: 1.47s
# 461:	learn: 0.4844045	total: 1.26s	remaining: 1.47s
# 462:	learn: 0.4842695	total: 1.26s	remaining: 1.46s
# 463:	learn: 0.4840462	total: 1.26s	remaining: 1.46s
# 464:	learn: 0.4838758	total: 1.26s	remaining: 1.46s
# 465:	learn: 0.4836908	total: 1.27s	remaining: 1.45s
# 466:	learn: 0.4835196	total: 1.27s	remaining: 1.45s
# 467:	learn: 0.4833306	total: 1.27s	remaining: 1.45s
# 468:	learn: 0.4830486	total: 1.27s	remaining: 1.44s
# 469:	learn: 0.4828033	total: 1.28s	remaining: 1.44s
# 470:	learn: 0.4825827	total: 1.28s	remaining: 1.44s
# 471:	learn: 0.4821876	total: 1.28s	remaining: 1.43s
# 472:	learn: 0.4820409	total: 1.28s	remaining: 1.43s
# 473:	learn: 0.4817484	total: 1.29s	remaining: 1.43s
# 474:	learn: 0.4816069	total: 1.29s	remaining: 1.42s
# 475:	learn: 0.4814366	total: 1.29s	remaining: 1.42s
# 476:	learn: 0.4811311	total: 1.29s	remaining: 1.42s
# 477:	learn: 0.4809612	total: 1.29s	remaining: 1.42s
# 478:	learn: 0.4806388	total: 1.3s	remaining: 1.41s
# 479:	learn: 0.4802407	total: 1.3s	remaining: 1.41s
# 480:	learn: 0.4801044	total: 1.3s	remaining: 1.41s
# 481:	learn: 0.4798823	total: 1.3s	remaining: 1.4s
# 482:	learn: 0.4796489	total: 1.31s	remaining: 1.4s
# 483:	learn: 0.4793810	total: 1.31s	remaining: 1.4s
# 484:	learn: 0.4790405	total: 1.31s	remaining: 1.39s
# 485:	learn: 0.4787734	total: 1.32s	remaining: 1.39s
# 486:	learn: 0.4785821	total: 1.32s	remaining: 1.39s
# 487:	learn: 0.4783512	total: 1.32s	remaining: 1.39s
# 488:	learn: 0.4780470	total: 1.32s	remaining: 1.38s
# 489:	learn: 0.4778426	total: 1.33s	remaining: 1.38s
# 490:	learn: 0.4776771	total: 1.33s	remaining: 1.38s
# 491:	learn: 0.4773508	total: 1.33s	remaining: 1.38s
# 492:	learn: 0.4771193	total: 1.33s	remaining: 1.37s
# 493:	learn: 0.4768462	total: 1.34s	remaining: 1.37s
# 494:	learn: 0.4766787	total: 1.34s	remaining: 1.37s
# 495:	learn: 0.4764910	total: 1.34s	remaining: 1.36s
# 496:	learn: 0.4762279	total: 1.34s	remaining: 1.36s
# 497:	learn: 0.4758947	total: 1.35s	remaining: 1.36s
# 498:	learn: 0.4755842	total: 1.35s	remaining: 1.35s
# 499:	learn: 0.4753394	total: 1.35s	remaining: 1.35s
# 500:	learn: 0.4749871	total: 1.35s	remaining: 1.35s
# 501:	learn: 0.4748025	total: 1.36s	remaining: 1.35s
# 502:	learn: 0.4744932	total: 1.36s	remaining: 1.34s
# 503:	learn: 0.4743521	total: 1.37s	remaining: 1.34s
# 504:	learn: 0.4740390	total: 1.37s	remaining: 1.34s
# 505:	learn: 0.4738743	total: 1.37s	remaining: 1.34s
# 506:	learn: 0.4736227	total: 1.37s	remaining: 1.34s
# 507:	learn: 0.4733466	total: 1.38s	remaining: 1.33s
# 508:	learn: 0.4731171	total: 1.38s	remaining: 1.33s
# 509:	learn: 0.4728903	total: 1.38s	remaining: 1.33s
# 510:	learn: 0.4726009	total: 1.38s	remaining: 1.32s
# 511:	learn: 0.4725005	total: 1.39s	remaining: 1.32s
# 512:	learn: 0.4722524	total: 1.39s	remaining: 1.32s
# 513:	learn: 0.4720494	total: 1.39s	remaining: 1.31s
# 514:	learn: 0.4716706	total: 1.39s	remaining: 1.31s
# 515:	learn: 0.4713610	total: 1.4s	remaining: 1.31s
# 516:	learn: 0.4710663	total: 1.4s	remaining: 1.31s
# 517:	learn: 0.4708188	total: 1.4s	remaining: 1.3s
# 518:	learn: 0.4705335	total: 1.41s	remaining: 1.3s
# 519:	learn: 0.4703869	total: 1.41s	remaining: 1.3s
# 520:	learn: 0.4701539	total: 1.41s	remaining: 1.3s
# 521:	learn: 0.4699224	total: 1.41s	remaining: 1.29s
# 522:	learn: 0.4696310	total: 1.42s	remaining: 1.29s
# 523:	learn: 0.4693923	total: 1.42s	remaining: 1.29s
# 524:	learn: 0.4691499	total: 1.42s	remaining: 1.28s
# 525:	learn: 0.4687863	total: 1.42s	remaining: 1.28s
# 526:	learn: 0.4686035	total: 1.43s	remaining: 1.28s
# 527:	learn: 0.4684908	total: 1.43s	remaining: 1.28s
# 528:	learn: 0.4682685	total: 1.43s	remaining: 1.27s
# 529:	learn: 0.4681234	total: 1.43s	remaining: 1.27s
# 530:	learn: 0.4678802	total: 1.44s	remaining: 1.27s
# 531:	learn: 0.4675167	total: 1.44s	remaining: 1.26s
# 532:	learn: 0.4672100	total: 1.44s	remaining: 1.26s
# 533:	learn: 0.4670055	total: 1.44s	remaining: 1.26s
# 534:	learn: 0.4668173	total: 1.45s	remaining: 1.26s
# 535:	learn: 0.4666331	total: 1.45s	remaining: 1.25s
# 536:	learn: 0.4664539	total: 1.45s	remaining: 1.25s
# 537:	learn: 0.4662927	total: 1.45s	remaining: 1.25s
# 538:	learn: 0.4660363	total: 1.45s	remaining: 1.24s
# 539:	learn: 0.4658252	total: 1.46s	remaining: 1.24s
# 540:	learn: 0.4656834	total: 1.46s	remaining: 1.24s
# 541:	learn: 0.4655230	total: 1.46s	remaining: 1.24s
# 542:	learn: 0.4653115	total: 1.46s	remaining: 1.23s
# 543:	learn: 0.4650283	total: 1.47s	remaining: 1.23s
# 544:	learn: 0.4647699	total: 1.47s	remaining: 1.23s
# 545:	learn: 0.4643786	total: 1.47s	remaining: 1.22s
# 546:	learn: 0.4642088	total: 1.47s	remaining: 1.22s
# 547:	learn: 0.4640194	total: 1.48s	remaining: 1.22s
# 548:	learn: 0.4638012	total: 1.48s	remaining: 1.21s
# 549:	learn: 0.4636296	total: 1.48s	remaining: 1.21s
# 550:	learn: 0.4634735	total: 1.48s	remaining: 1.21s
# 551:	learn: 0.4633002	total: 1.49s	remaining: 1.21s
# 552:	learn: 0.4630572	total: 1.49s	remaining: 1.2s
# 553:	learn: 0.4627860	total: 1.49s	remaining: 1.2s
# 554:	learn: 0.4625959	total: 1.49s	remaining: 1.2s
# 555:	learn: 0.4623005	total: 1.5s	remaining: 1.2s
# 556:	learn: 0.4621362	total: 1.5s	remaining: 1.19s
# 557:	learn: 0.4620241	total: 1.5s	remaining: 1.19s
# 558:	learn: 0.4618703	total: 1.5s	remaining: 1.19s
# 559:	learn: 0.4617563	total: 1.51s	remaining: 1.18s
# 560:	learn: 0.4615317	total: 1.51s	remaining: 1.18s
# 561:	learn: 0.4613107	total: 1.51s	remaining: 1.18s
# 562:	learn: 0.4611978	total: 1.51s	remaining: 1.17s
# 563:	learn: 0.4609099	total: 1.51s	remaining: 1.17s
# 564:	learn: 0.4606933	total: 1.52s	remaining: 1.17s
# 565:	learn: 0.4605203	total: 1.52s	remaining: 1.17s
# 566:	learn: 0.4603076	total: 1.52s	remaining: 1.16s
# 567:	learn: 0.4601778	total: 1.52s	remaining: 1.16s
# 568:	learn: 0.4599500	total: 1.53s	remaining: 1.16s
# 569:	learn: 0.4597653	total: 1.53s	remaining: 1.15s
# 570:	learn: 0.4596323	total: 1.53s	remaining: 1.15s
# 571:	learn: 0.4595053	total: 1.53s	remaining: 1.15s
# 572:	learn: 0.4593367	total: 1.54s	remaining: 1.15s
# 573:	learn: 0.4590840	total: 1.54s	remaining: 1.14s
# 574:	learn: 0.4589952	total: 1.54s	remaining: 1.14s
# 575:	learn: 0.4588188	total: 1.54s	remaining: 1.14s
# 576:	learn: 0.4585172	total: 1.55s	remaining: 1.13s
# 577:	learn: 0.4582941	total: 1.55s	remaining: 1.13s
# 578:	learn: 0.4580280	total: 1.55s	remaining: 1.13s
# 579:	learn: 0.4577934	total: 1.55s	remaining: 1.12s
# 580:	learn: 0.4575470	total: 1.56s	remaining: 1.12s
# 581:	learn: 0.4572400	total: 1.56s	remaining: 1.12s
# 582:	learn: 0.4571287	total: 1.56s	remaining: 1.12s
# 583:	learn: 0.4569184	total: 1.56s	remaining: 1.11s
# 584:	learn: 0.4566654	total: 1.57s	remaining: 1.11s
# 585:	learn: 0.4564905	total: 1.57s	remaining: 1.11s
# 586:	learn: 0.4563118	total: 1.57s	remaining: 1.11s
# 587:	learn: 0.4561523	total: 1.57s	remaining: 1.1s
# 588:	learn: 0.4560508	total: 1.58s	remaining: 1.1s
# 589:	learn: 0.4559455	total: 1.58s	remaining: 1.1s
# 590:	learn: 0.4557917	total: 1.58s	remaining: 1.09s
# 591:	learn: 0.4554525	total: 1.58s	remaining: 1.09s
# 592:	learn: 0.4552323	total: 1.59s	remaining: 1.09s
# 593:	learn: 0.4550226	total: 1.59s	remaining: 1.09s
# 594:	learn: 0.4547208	total: 1.59s	remaining: 1.08s
# 595:	learn: 0.4545653	total: 1.59s	remaining: 1.08s
# 596:	learn: 0.4543818	total: 1.6s	remaining: 1.08s
# 597:	learn: 0.4541932	total: 1.6s	remaining: 1.08s
# 598:	learn: 0.4539336	total: 1.6s	remaining: 1.07s
# 599:	learn: 0.4537672	total: 1.6s	remaining: 1.07s
# 600:	learn: 0.4535404	total: 1.61s	remaining: 1.07s
# 601:	learn: 0.4532679	total: 1.61s	remaining: 1.06s
# 602:	learn: 0.4530327	total: 1.61s	remaining: 1.06s
# 603:	learn: 0.4528519	total: 1.62s	remaining: 1.06s
# 604:	learn: 0.4525902	total: 1.62s	remaining: 1.06s
# 605:	learn: 0.4523690	total: 1.62s	remaining: 1.05s
# 606:	learn: 0.4522625	total: 1.63s	remaining: 1.05s
# 607:	learn: 0.4520914	total: 1.63s	remaining: 1.05s
# 608:	learn: 0.4519210	total: 1.63s	remaining: 1.05s
# 609:	learn: 0.4516907	total: 1.63s	remaining: 1.04s
# 610:	learn: 0.4514707	total: 1.64s	remaining: 1.04s
# 611:	learn: 0.4513058	total: 1.64s	remaining: 1.04s
# 612:	learn: 0.4510657	total: 1.64s	remaining: 1.04s
# 613:	learn: 0.4507643	total: 1.64s	remaining: 1.03s
# 614:	learn: 0.4505301	total: 1.65s	remaining: 1.03s
# 615:	learn: 0.4502733	total: 1.65s	remaining: 1.03s
# 616:	learn: 0.4501065	total: 1.65s	remaining: 1.02s
# 617:	learn: 0.4498883	total: 1.65s	remaining: 1.02s
# 618:	learn: 0.4498199	total: 1.66s	remaining: 1.02s
# 619:	learn: 0.4496212	total: 1.66s	remaining: 1.02s
# 620:	learn: 0.4494065	total: 1.66s	remaining: 1.01s
# 621:	learn: 0.4492489	total: 1.66s	remaining: 1.01s
# 622:	learn: 0.4490693	total: 1.67s	remaining: 1.01s
# 623:	learn: 0.4488961	total: 1.67s	remaining: 1.01s
# 624:	learn: 0.4486373	total: 1.67s	remaining: 1s
# 625:	learn: 0.4484065	total: 1.68s	remaining: 1s
# 626:	learn: 0.4482004	total: 1.68s	remaining: 998ms
# 627:	learn: 0.4479536	total: 1.68s	remaining: 995ms
# 628:	learn: 0.4478854	total: 1.68s	remaining: 992ms
# 629:	learn: 0.4476932	total: 1.68s	remaining: 989ms
# 630:	learn: 0.4474901	total: 1.69s	remaining: 986ms
# 631:	learn: 0.4472503	total: 1.69s	remaining: 984ms
# 632:	learn: 0.4470266	total: 1.69s	remaining: 981ms
# 633:	learn: 0.4467957	total: 1.69s	remaining: 978ms
# 634:	learn: 0.4466083	total: 1.7s	remaining: 975ms
# 635:	learn: 0.4463130	total: 1.7s	remaining: 972ms
# 636:	learn: 0.4462097	total: 1.7s	remaining: 969ms
# 637:	learn: 0.4459805	total: 1.7s	remaining: 967ms
# 638:	learn: 0.4457162	total: 1.71s	remaining: 964ms
# 639:	learn: 0.4455702	total: 1.71s	remaining: 961ms
# 640:	learn: 0.4454677	total: 1.71s	remaining: 958ms
# 641:	learn: 0.4453042	total: 1.71s	remaining: 955ms
# 642:	learn: 0.4450525	total: 1.72s	remaining: 952ms
# 643:	learn: 0.4447953	total: 1.72s	remaining: 950ms
# 644:	learn: 0.4445242	total: 1.72s	remaining: 947ms
# 645:	learn: 0.4442926	total: 1.72s	remaining: 944ms
# 646:	learn: 0.4441765	total: 1.72s	remaining: 941ms
# 647:	learn: 0.4440215	total: 1.73s	remaining: 938ms
# 648:	learn: 0.4437919	total: 1.73s	remaining: 935ms
# 649:	learn: 0.4435476	total: 1.73s	remaining: 933ms
# 650:	learn: 0.4434494	total: 1.73s	remaining: 930ms
# 651:	learn: 0.4433705	total: 1.74s	remaining: 927ms
# 652:	learn: 0.4432137	total: 1.74s	remaining: 924ms
# 653:	learn: 0.4430700	total: 1.74s	remaining: 921ms
# 654:	learn: 0.4429111	total: 1.74s	remaining: 918ms
# 655:	learn: 0.4425094	total: 1.75s	remaining: 916ms
# 656:	learn: 0.4423216	total: 1.75s	remaining: 913ms
# 657:	learn: 0.4421153	total: 1.75s	remaining: 910ms
# 658:	learn: 0.4419945	total: 1.75s	remaining: 908ms
# 659:	learn: 0.4417711	total: 1.76s	remaining: 905ms
# 660:	learn: 0.4415764	total: 1.76s	remaining: 902ms
# 661:	learn: 0.4413868	total: 1.76s	remaining: 900ms
# 662:	learn: 0.4412174	total: 1.76s	remaining: 897ms
# 663:	learn: 0.4411045	total: 1.77s	remaining: 894ms
# 664:	learn: 0.4409421	total: 1.77s	remaining: 891ms
# 665:	learn: 0.4407946	total: 1.77s	remaining: 889ms
# 666:	learn: 0.4405108	total: 1.77s	remaining: 886ms
# 667:	learn: 0.4403233	total: 1.78s	remaining: 884ms
# 668:	learn: 0.4401267	total: 1.78s	remaining: 882ms
# 669:	learn: 0.4398235	total: 1.78s	remaining: 879ms
# 670:	learn: 0.4394314	total: 1.79s	remaining: 877ms
# 671:	learn: 0.4391563	total: 1.79s	remaining: 874ms
# 672:	learn: 0.4389318	total: 1.79s	remaining: 871ms
# 673:	learn: 0.4386667	total: 1.79s	remaining: 868ms
# 674:	learn: 0.4383687	total: 1.8s	remaining: 866ms
# 675:	learn: 0.4382078	total: 1.8s	remaining: 863ms
# 676:	learn: 0.4379873	total: 1.8s	remaining: 860ms
# 677:	learn: 0.4377937	total: 1.8s	remaining: 857ms
# 678:	learn: 0.4376781	total: 1.81s	remaining: 855ms
# 679:	learn: 0.4373265	total: 1.81s	remaining: 852ms
# 680:	learn: 0.4371582	total: 1.81s	remaining: 849ms
# 681:	learn: 0.4368628	total: 1.81s	remaining: 846ms
# 682:	learn: 0.4366603	total: 1.82s	remaining: 844ms
# 683:	learn: 0.4365495	total: 1.82s	remaining: 841ms
# 684:	learn: 0.4363379	total: 1.82s	remaining: 838ms
# 685:	learn: 0.4362041	total: 1.82s	remaining: 835ms
# 686:	learn: 0.4359051	total: 1.83s	remaining: 833ms
# 687:	learn: 0.4357999	total: 1.83s	remaining: 830ms
# 688:	learn: 0.4355146	total: 1.83s	remaining: 827ms
# 689:	learn: 0.4354164	total: 1.83s	remaining: 825ms
# 690:	learn: 0.4351746	total: 1.84s	remaining: 822ms
# 691:	learn: 0.4349608	total: 1.84s	remaining: 819ms
# 692:	learn: 0.4346030	total: 1.85s	remaining: 818ms
# 693:	learn: 0.4343620	total: 1.85s	remaining: 816ms
# 694:	learn: 0.4340529	total: 1.85s	remaining: 813ms
# 695:	learn: 0.4337224	total: 1.85s	remaining: 811ms
# 696:	learn: 0.4335546	total: 1.86s	remaining: 808ms
# 697:	learn: 0.4333614	total: 1.86s	remaining: 805ms
# 698:	learn: 0.4331351	total: 1.86s	remaining: 802ms
# 699:	learn: 0.4329557	total: 1.86s	remaining: 800ms
# 700:	learn: 0.4328354	total: 1.87s	remaining: 797ms
# 701:	learn: 0.4324960	total: 1.87s	remaining: 794ms
# 702:	learn: 0.4323266	total: 1.87s	remaining: 791ms
# 703:	learn: 0.4321974	total: 1.88s	remaining: 788ms
# 704:	learn: 0.4320053	total: 1.88s	remaining: 786ms
# 705:	learn: 0.4318478	total: 1.88s	remaining: 783ms
# 706:	learn: 0.4316946	total: 1.88s	remaining: 781ms
# 707:	learn: 0.4313471	total: 1.89s	remaining: 778ms
# 708:	learn: 0.4311119	total: 1.89s	remaining: 775ms
# 709:	learn: 0.4308745	total: 1.89s	remaining: 772ms
# 710:	learn: 0.4306895	total: 1.89s	remaining: 770ms
# 711:	learn: 0.4304601	total: 1.9s	remaining: 767ms
# 712:	learn: 0.4302368	total: 1.9s	remaining: 764ms
# 713:	learn: 0.4299137	total: 1.9s	remaining: 761ms
# 714:	learn: 0.4297225	total: 1.9s	remaining: 759ms
# 715:	learn: 0.4295296	total: 1.91s	remaining: 756ms
# 716:	learn: 0.4293726	total: 1.91s	remaining: 753ms
# 717:	learn: 0.4291277	total: 1.91s	remaining: 751ms
# 718:	learn: 0.4289656	total: 1.91s	remaining: 748ms
# 719:	learn: 0.4287615	total: 1.92s	remaining: 745ms
# 720:	learn: 0.4285529	total: 1.92s	remaining: 743ms
# 721:	learn: 0.4282767	total: 1.92s	remaining: 740ms
# 722:	learn: 0.4280221	total: 1.92s	remaining: 737ms
# 723:	learn: 0.4279357	total: 1.93s	remaining: 735ms
# 724:	learn: 0.4276829	total: 1.93s	remaining: 732ms
# 725:	learn: 0.4275016	total: 1.93s	remaining: 729ms
# 726:	learn: 0.4273251	total: 1.93s	remaining: 727ms
# 727:	learn: 0.4270371	total: 1.94s	remaining: 724ms
# 728:	learn: 0.4269585	total: 1.94s	remaining: 721ms
# 729:	learn: 0.4265977	total: 1.94s	remaining: 718ms
# 730:	learn: 0.4264432	total: 1.95s	remaining: 716ms
# 731:	learn: 0.4261456	total: 1.95s	remaining: 714ms
# 732:	learn: 0.4259187	total: 1.95s	remaining: 711ms
# 733:	learn: 0.4257933	total: 1.95s	remaining: 708ms
# 734:	learn: 0.4256143	total: 1.96s	remaining: 706ms
# 735:	learn: 0.4254375	total: 1.96s	remaining: 703ms
# 736:	learn: 0.4252911	total: 1.96s	remaining: 700ms
# 737:	learn: 0.4250418	total: 1.97s	remaining: 698ms
# 738:	learn: 0.4248640	total: 1.97s	remaining: 695ms
# 739:	learn: 0.4247367	total: 1.97s	remaining: 692ms
# 740:	learn: 0.4245359	total: 1.97s	remaining: 690ms
# 741:	learn: 0.4243650	total: 1.98s	remaining: 687ms
# 742:	learn: 0.4242158	total: 1.98s	remaining: 684ms
# 743:	learn: 0.4240328	total: 1.98s	remaining: 682ms
# 744:	learn: 0.4236727	total: 1.98s	remaining: 679ms
# 745:	learn: 0.4234706	total: 1.99s	remaining: 676ms
# 746:	learn: 0.4232217	total: 1.99s	remaining: 673ms
# 747:	learn: 0.4229519	total: 1.99s	remaining: 671ms
# 748:	learn: 0.4228438	total: 1.99s	remaining: 668ms
# 749:	learn: 0.4226248	total: 2s	remaining: 665ms
# 750:	learn: 0.4224088	total: 2s	remaining: 663ms
# 751:	learn: 0.4221836	total: 2s	remaining: 660ms
# 752:	learn: 0.4219420	total: 2s	remaining: 657ms
# 753:	learn: 0.4216699	total: 2s	remaining: 654ms
# 754:	learn: 0.4215441	total: 2.01s	remaining: 652ms
# 755:	learn: 0.4212934	total: 2.01s	remaining: 649ms
# 756:	learn: 0.4210166	total: 2.01s	remaining: 646ms
# 757:	learn: 0.4208579	total: 2.02s	remaining: 644ms
# 758:	learn: 0.4206709	total: 2.02s	remaining: 641ms
# 759:	learn: 0.4205094	total: 2.02s	remaining: 638ms
# 760:	learn: 0.4202920	total: 2.02s	remaining: 636ms
# 761:	learn: 0.4200781	total: 2.03s	remaining: 633ms
# 762:	learn: 0.4199235	total: 2.03s	remaining: 630ms
# 763:	learn: 0.4196488	total: 2.03s	remaining: 627ms
# 764:	learn: 0.4194287	total: 2.03s	remaining: 625ms
# 765:	learn: 0.4192743	total: 2.04s	remaining: 622ms
# 766:	learn: 0.4190274	total: 2.04s	remaining: 619ms
# 767:	learn: 0.4188681	total: 2.04s	remaining: 616ms
# 768:	learn: 0.4187586	total: 2.04s	remaining: 614ms
# 769:	learn: 0.4185011	total: 2.04s	remaining: 611ms
# 770:	learn: 0.4182530	total: 2.05s	remaining: 608ms
# 771:	learn: 0.4180192	total: 2.05s	remaining: 605ms
# 772:	learn: 0.4177561	total: 2.05s	remaining: 603ms
# 773:	learn: 0.4175541	total: 2.05s	remaining: 600ms
# 774:	learn: 0.4173821	total: 2.06s	remaining: 597ms
# 775:	learn: 0.4171753	total: 2.06s	remaining: 594ms
# 776:	learn: 0.4169157	total: 2.06s	remaining: 592ms
# 777:	learn: 0.4167644	total: 2.06s	remaining: 589ms
# 778:	learn: 0.4165938	total: 2.07s	remaining: 586ms
# 779:	learn: 0.4164513	total: 2.07s	remaining: 584ms
# 780:	learn: 0.4162791	total: 2.07s	remaining: 581ms
# 781:	learn: 0.4159861	total: 2.07s	remaining: 578ms
# 782:	learn: 0.4157701	total: 2.08s	remaining: 575ms
# 783:	learn: 0.4155156	total: 2.08s	remaining: 573ms
# 784:	learn: 0.4152565	total: 2.08s	remaining: 570ms
# 785:	learn: 0.4150332	total: 2.08s	remaining: 567ms
# 786:	learn: 0.4147972	total: 2.08s	remaining: 564ms
# 787:	learn: 0.4144756	total: 2.09s	remaining: 562ms
# 788:	learn: 0.4143282	total: 2.09s	remaining: 559ms
# 789:	learn: 0.4141063	total: 2.09s	remaining: 556ms
# 790:	learn: 0.4139415	total: 2.09s	remaining: 554ms
# 791:	learn: 0.4137564	total: 2.1s	remaining: 551ms
# 792:	learn: 0.4134355	total: 2.1s	remaining: 548ms
# 793:	learn: 0.4132669	total: 2.1s	remaining: 545ms
# 794:	learn: 0.4131420	total: 2.1s	remaining: 543ms
# 795:	learn: 0.4130640	total: 2.11s	remaining: 540ms
# 796:	learn: 0.4128155	total: 2.11s	remaining: 537ms
# 797:	learn: 0.4126449	total: 2.11s	remaining: 534ms
# 798:	learn: 0.4123890	total: 2.11s	remaining: 532ms
# 799:	learn: 0.4121308	total: 2.12s	remaining: 529ms
# 800:	learn: 0.4119061	total: 2.12s	remaining: 526ms
# 801:	learn: 0.4116751	total: 2.12s	remaining: 524ms
# 802:	learn: 0.4113577	total: 2.12s	remaining: 521ms
# 803:	learn: 0.4112095	total: 2.13s	remaining: 518ms
# 804:	learn: 0.4111135	total: 2.13s	remaining: 515ms
# 805:	learn: 0.4108124	total: 2.13s	remaining: 513ms
# 806:	learn: 0.4106362	total: 2.13s	remaining: 510ms
# 807:	learn: 0.4104839	total: 2.13s	remaining: 507ms
# 808:	learn: 0.4103535	total: 2.14s	remaining: 505ms
# 809:	learn: 0.4100186	total: 2.14s	remaining: 502ms
# 810:	learn: 0.4099079	total: 2.14s	remaining: 499ms
# 811:	learn: 0.4098147	total: 2.15s	remaining: 497ms
# 812:	learn: 0.4095821	total: 2.15s	remaining: 494ms
# 813:	learn: 0.4094239	total: 2.15s	remaining: 491ms
# 814:	learn: 0.4093155	total: 2.15s	remaining: 489ms
# 815:	learn: 0.4091437	total: 2.15s	remaining: 486ms
# 816:	learn: 0.4088978	total: 2.16s	remaining: 483ms
# 817:	learn: 0.4087640	total: 2.16s	remaining: 480ms
# 818:	learn: 0.4085481	total: 2.16s	remaining: 478ms
# 819:	learn: 0.4083544	total: 2.16s	remaining: 475ms
# 820:	learn: 0.4081774	total: 2.17s	remaining: 472ms
# 821:	learn: 0.4080198	total: 2.17s	remaining: 470ms
# 822:	learn: 0.4077260	total: 2.17s	remaining: 467ms
# 823:	learn: 0.4074938	total: 2.17s	remaining: 464ms
# 824:	learn: 0.4073197	total: 2.18s	remaining: 462ms
# 825:	learn: 0.4070717	total: 2.18s	remaining: 459ms
# 826:	learn: 0.4068761	total: 2.18s	remaining: 456ms
# 827:	learn: 0.4067398	total: 2.18s	remaining: 454ms
# 828:	learn: 0.4064977	total: 2.19s	remaining: 451ms
# 829:	learn: 0.4064087	total: 2.19s	remaining: 448ms
# 830:	learn: 0.4062293	total: 2.19s	remaining: 446ms
# 831:	learn: 0.4060305	total: 2.19s	remaining: 443ms
# 832:	learn: 0.4058190	total: 2.2s	remaining: 440ms
# 833:	learn: 0.4055830	total: 2.2s	remaining: 438ms
# 834:	learn: 0.4054320	total: 2.2s	remaining: 435ms
# 835:	learn: 0.4052605	total: 2.2s	remaining: 432ms
# 836:	learn: 0.4051823	total: 2.21s	remaining: 430ms
# 837:	learn: 0.4049725	total: 2.21s	remaining: 427ms
# 838:	learn: 0.4047160	total: 2.21s	remaining: 424ms
# 839:	learn: 0.4046072	total: 2.21s	remaining: 422ms
# 840:	learn: 0.4044058	total: 2.22s	remaining: 419ms
# 841:	learn: 0.4041757	total: 2.22s	remaining: 416ms
# 842:	learn: 0.4039642	total: 2.22s	remaining: 414ms
# 843:	learn: 0.4037785	total: 2.22s	remaining: 411ms
# 844:	learn: 0.4035168	total: 2.23s	remaining: 408ms
# 845:	learn: 0.4033464	total: 2.23s	remaining: 406ms
# 846:	learn: 0.4031351	total: 2.23s	remaining: 403ms
# 847:	learn: 0.4029085	total: 2.23s	remaining: 400ms
# 848:	learn: 0.4027372	total: 2.23s	remaining: 398ms
# 849:	learn: 0.4025715	total: 2.24s	remaining: 395ms
# 850:	learn: 0.4023064	total: 2.24s	remaining: 393ms
# 851:	learn: 0.4019461	total: 2.25s	remaining: 390ms
# 852:	learn: 0.4017610	total: 2.25s	remaining: 387ms
# 853:	learn: 0.4014835	total: 2.25s	remaining: 385ms
# 854:	learn: 0.4012089	total: 2.25s	remaining: 382ms
# 855:	learn: 0.4009018	total: 2.25s	remaining: 379ms
# 856:	learn: 0.4007929	total: 2.26s	remaining: 377ms
# 857:	learn: 0.4005804	total: 2.26s	remaining: 374ms
# 858:	learn: 0.4003964	total: 2.26s	remaining: 371ms
# 859:	learn: 0.4001905	total: 2.26s	remaining: 369ms
# 860:	learn: 0.4000706	total: 2.27s	remaining: 366ms
# 861:	learn: 0.3998180	total: 2.27s	remaining: 363ms
# 862:	learn: 0.3996330	total: 2.27s	remaining: 361ms
# 863:	learn: 0.3994613	total: 2.27s	remaining: 358ms
# 864:	learn: 0.3991767	total: 2.28s	remaining: 355ms
# 865:	learn: 0.3988977	total: 2.28s	remaining: 353ms
# 866:	learn: 0.3987649	total: 2.28s	remaining: 350ms
# 867:	learn: 0.3985918	total: 2.28s	remaining: 347ms
# 868:	learn: 0.3983617	total: 2.29s	remaining: 345ms
# 869:	learn: 0.3981829	total: 2.29s	remaining: 342ms
# 870:	learn: 0.3981044	total: 2.29s	remaining: 339ms
# 871:	learn: 0.3977939	total: 2.29s	remaining: 337ms
# 872:	learn: 0.3976365	total: 2.3s	remaining: 334ms
# 873:	learn: 0.3975127	total: 2.3s	remaining: 332ms
# 874:	learn: 0.3973348	total: 2.3s	remaining: 329ms
# 875:	learn: 0.3971928	total: 2.3s	remaining: 326ms
# 876:	learn: 0.3969822	total: 2.31s	remaining: 324ms
# 877:	learn: 0.3967277	total: 2.31s	remaining: 321ms
# 878:	learn: 0.3965105	total: 2.31s	remaining: 318ms
# 879:	learn: 0.3963871	total: 2.31s	remaining: 316ms
# 880:	learn: 0.3962082	total: 2.32s	remaining: 313ms
# 881:	learn: 0.3960562	total: 2.32s	remaining: 310ms
# 882:	learn: 0.3958966	total: 2.32s	remaining: 308ms
# 883:	learn: 0.3956897	total: 2.32s	remaining: 305ms
# 884:	learn: 0.3954424	total: 2.33s	remaining: 302ms
# 885:	learn: 0.3952033	total: 2.33s	remaining: 300ms
# 886:	learn: 0.3949253	total: 2.33s	remaining: 297ms
# 887:	learn: 0.3947935	total: 2.33s	remaining: 294ms
# 888:	learn: 0.3945846	total: 2.34s	remaining: 292ms
# 889:	learn: 0.3944383	total: 2.34s	remaining: 289ms
# 890:	learn: 0.3942247	total: 2.34s	remaining: 287ms
# 891:	learn: 0.3940736	total: 2.35s	remaining: 284ms
# 892:	learn: 0.3938382	total: 2.35s	remaining: 282ms
# 893:	learn: 0.3935899	total: 2.35s	remaining: 279ms
# 894:	learn: 0.3934212	total: 2.35s	remaining: 276ms
# 895:	learn: 0.3932582	total: 2.36s	remaining: 274ms
# 896:	learn: 0.3930948	total: 2.36s	remaining: 271ms
# 897:	learn: 0.3929378	total: 2.36s	remaining: 268ms
# 898:	learn: 0.3926615	total: 2.37s	remaining: 266ms
# 899:	learn: 0.3925262	total: 2.37s	remaining: 263ms
# 900:	learn: 0.3922469	total: 2.37s	remaining: 260ms
# 901:	learn: 0.3920810	total: 2.37s	remaining: 258ms
# 902:	learn: 0.3918235	total: 2.38s	remaining: 255ms
# 903:	learn: 0.3917040	total: 2.38s	remaining: 253ms
# 904:	learn: 0.3915288	total: 2.38s	remaining: 250ms
# 905:	learn: 0.3913906	total: 2.38s	remaining: 247ms
# 906:	learn: 0.3912097	total: 2.38s	remaining: 245ms
# 907:	learn: 0.3910335	total: 2.39s	remaining: 242ms
# 908:	learn: 0.3908281	total: 2.39s	remaining: 239ms
# 909:	learn: 0.3907047	total: 2.39s	remaining: 237ms
# 910:	learn: 0.3904252	total: 2.4s	remaining: 234ms
# 911:	learn: 0.3901807	total: 2.4s	remaining: 231ms
# 912:	learn: 0.3899897	total: 2.4s	remaining: 229ms
# 913:	learn: 0.3898105	total: 2.4s	remaining: 226ms
# 914:	learn: 0.3895558	total: 2.4s	remaining: 223ms
# 915:	learn: 0.3894039	total: 2.41s	remaining: 221ms
# 916:	learn: 0.3891250	total: 2.41s	remaining: 218ms
# 917:	learn: 0.3888944	total: 2.41s	remaining: 215ms
# 918:	learn: 0.3887248	total: 2.41s	remaining: 213ms
# 919:	learn: 0.3884495	total: 2.42s	remaining: 210ms
# 920:	learn: 0.3883384	total: 2.42s	remaining: 207ms
# 921:	learn: 0.3881150	total: 2.42s	remaining: 205ms
# 922:	learn: 0.3879464	total: 2.42s	remaining: 202ms
# 923:	learn: 0.3877871	total: 2.42s	remaining: 200ms
# 924:	learn: 0.3876968	total: 2.43s	remaining: 197ms
# 925:	learn: 0.3875135	total: 2.43s	remaining: 194ms
# 926:	learn: 0.3874417	total: 2.43s	remaining: 192ms
# 927:	learn: 0.3873421	total: 2.44s	remaining: 189ms
# 928:	learn: 0.3871522	total: 2.44s	remaining: 186ms
# 929:	learn: 0.3869979	total: 2.44s	remaining: 184ms
# 930:	learn: 0.3867587	total: 2.44s	remaining: 181ms
# 931:	learn: 0.3865144	total: 2.44s	remaining: 178ms
# 932:	learn: 0.3862925	total: 2.45s	remaining: 176ms
# 933:	learn: 0.3860127	total: 2.45s	remaining: 173ms
# 934:	learn: 0.3858295	total: 2.45s	remaining: 171ms
# 935:	learn: 0.3856770	total: 2.46s	remaining: 168ms
# 936:	learn: 0.3854651	total: 2.46s	remaining: 165ms
# 937:	learn: 0.3851641	total: 2.46s	remaining: 163ms
# 938:	learn: 0.3849558	total: 2.46s	remaining: 160ms
# 939:	learn: 0.3847084	total: 2.47s	remaining: 157ms
# 940:	learn: 0.3846152	total: 2.47s	remaining: 155ms
# 941:	learn: 0.3844749	total: 2.47s	remaining: 152ms
# 942:	learn: 0.3843921	total: 2.47s	remaining: 150ms
# 943:	learn: 0.3841878	total: 2.48s	remaining: 147ms
# 944:	learn: 0.3840191	total: 2.48s	remaining: 144ms
# 945:	learn: 0.3838011	total: 2.48s	remaining: 142ms
# 946:	learn: 0.3836465	total: 2.48s	remaining: 139ms
# 947:	learn: 0.3835568	total: 2.49s	remaining: 136ms
# 948:	learn: 0.3833149	total: 2.49s	remaining: 134ms
# 949:	learn: 0.3831832	total: 2.49s	remaining: 131ms
# 950:	learn: 0.3827796	total: 2.49s	remaining: 129ms
# 951:	learn: 0.3825922	total: 2.5s	remaining: 126ms
# 952:	learn: 0.3824268	total: 2.5s	remaining: 123ms
# 953:	learn: 0.3821818	total: 2.5s	remaining: 121ms
# 954:	learn: 0.3819463	total: 2.5s	remaining: 118ms
# 955:	learn: 0.3817704	total: 2.51s	remaining: 115ms
# 956:	learn: 0.3815176	total: 2.51s	remaining: 113ms
# 957:	learn: 0.3814357	total: 2.51s	remaining: 110ms
# 958:	learn: 0.3812083	total: 2.51s	remaining: 108ms
# 959:	learn: 0.3810100	total: 2.52s	remaining: 105ms
# 960:	learn: 0.3808549	total: 2.52s	remaining: 102ms
# 961:	learn: 0.3806675	total: 2.52s	remaining: 99.6ms
# 962:	learn: 0.3805849	total: 2.52s	remaining: 97ms
# 963:	learn: 0.3803303	total: 2.53s	remaining: 94.4ms
# 964:	learn: 0.3802341	total: 2.53s	remaining: 91.8ms
# 965:	learn: 0.3800471	total: 2.53s	remaining: 89.2ms
# 966:	learn: 0.3799496	total: 2.54s	remaining: 86.5ms
# 967:	learn: 0.3797206	total: 2.54s	remaining: 83.9ms
# 968:	learn: 0.3795596	total: 2.54s	remaining: 81.3ms
# 969:	learn: 0.3793641	total: 2.54s	remaining: 78.6ms
# 970:	learn: 0.3792785	total: 2.54s	remaining: 76ms
# 971:	learn: 0.3791431	total: 2.55s	remaining: 73.4ms
# 972:	learn: 0.3790388	total: 2.55s	remaining: 70.8ms
# 973:	learn: 0.3789016	total: 2.55s	remaining: 68.1ms
# 974:	learn: 0.3787479	total: 2.55s	remaining: 65.5ms
# 975:	learn: 0.3785279	total: 2.56s	remaining: 62.9ms
# 976:	learn: 0.3783437	total: 2.56s	remaining: 60.3ms
# 977:	learn: 0.3780678	total: 2.56s	remaining: 57.6ms
# 978:	learn: 0.3778254	total: 2.56s	remaining: 55ms
# 979:	learn: 0.3776249	total: 2.57s	remaining: 52.4ms
# 980:	learn: 0.3773934	total: 2.57s	remaining: 49.8ms
# 981:	learn: 0.3772109	total: 2.57s	remaining: 47.1ms
# 982:	learn: 0.3771014	total: 2.57s	remaining: 44.5ms
# 983:	learn: 0.3769821	total: 2.58s	remaining: 41.9ms
# 984:	learn: 0.3767979	total: 2.58s	remaining: 39.3ms
# 985:	learn: 0.3766657	total: 2.58s	remaining: 36.7ms
# 986:	learn: 0.3764691	total: 2.58s	remaining: 34ms
# 987:	learn: 0.3763081	total: 2.58s	remaining: 31.4ms
# 988:	learn: 0.3760178	total: 2.59s	remaining: 28.8ms
# 989:	learn: 0.3758846	total: 2.59s	remaining: 26.2ms
# 990:	learn: 0.3756303	total: 2.59s	remaining: 23.5ms
# 991:	learn: 0.3755154	total: 2.6s	remaining: 20.9ms
# 992:	learn: 0.3753711	total: 2.6s	remaining: 18.3ms
# 993:	learn: 0.3751583	total: 2.6s	remaining: 15.7ms
# 994:	learn: 0.3749723	total: 2.6s	remaining: 13.1ms
# 995:	learn: 0.3748104	total: 2.6s	remaining: 10.5ms
# 996:	learn: 0.3746582	total: 2.61s	remaining: 7.85ms
# 997:	learn: 0.3745204	total: 2.61s	remaining: 5.23ms
# 998:	learn: 0.3743904	total: 2.61s	remaining: 2.61ms
# 999:	learn: 0.3741264	total: 2.61s	remaining: 0us

# %% [markdown]
# ### Ensemble

# %%
#Using random forests as the meta model (final_estimator). Note that random forest will require tuning
ensemble_model = StackingClassifier(estimators=[('ada',model_Ada),('XGB',model_XGB),('GradBoost',model_GradBoost),('RF',model_randomForest), 
 ('Cat',model_cat),('BaggedTree',model_BaggedTree)],
                                   final_estimator=RandomForestClassifier(n_estimators=500, max_features=1,
                                                                          random_state=1,oob_score=True),n_jobs=-1,
                                   cv = StratifiedKFold(n_splits=5,shuffle=True,random_state=1))
ensemble_model.fit(X_train,y_train)
# Out:
# StackingClassifier(cv=StratifiedKFold(n_splits=5, random_state=1, shuffle=True),
#                    estimators=[('ada',
#                                 AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=15),
#                                                    learning_rate=0.01,
#                                                    n_estimators=2000,
#                                                    random_state=1)),
#                                ('XGB',
#                                 XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_by_tree=0.25,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,...
#                                                        max_features=4,
#                                                        max_leaf_nodes=36,
#                                                        oob_score=True,
#                                                        random_state=1)),
#                                ('Cat',
#                                 <catboost.core.CatBoostClassifier object at 0x7fae90c75c00>),
#                                ('BaggedTree',
#                                 BaggingClassifier(base_estimator=DecisionTreeClassifier(),
#                                                   n_estimators=150, n_jobs=-1,
#                                                   random_state=1))],
#                    final_estimator=RandomForestClassifier(max_features=1,
#                                                           n_estimators=500,
#                                                           oob_score=True,
#                                                           random_state=1),
#                    n_jobs=-1)

# %%
#Model based on the optimal parameters
model = ensemble_model

# Note that we are using the cross-validated predicted probabilities, instead of directly using the 
# predicted probabilities on train data, as the model may be overfitting on the train data, and 
# may lead to misleading results
cross_val_ypred = cross_val_predict(StackingClassifier(estimators=[('ada',model_Ada),('XGB',model_XGB),('GradBoost',model_GradBoost),('RF',model_randomForest), ('Cat',model_cat),('BaggedTree',model_BaggedTree)], X_train,y_train, cv = 5, method = 'predict_proba'))

p, r, thresholds = precision_recall_curve(y_train, cross_val_ypred[:,1])
acc = np.ndarray(shape = (len(thresholds),))
i = 0
for th in thresholds:
    y_pred = cross_val_ypred[:,1] > th
    y_pred = y_pred.astype(int)
    acc[i] = accuracy_score(y_pred, y_train)
    i = i + 1
def plot_precision_recall_vs_threshold(precisions, recalls, thresholds):
    plt.figure(figsize=(8, 8))
    plt.title("Precision and Recall Scores as a function of the decision threshold")
    plt.plot(thresholds, precisions[:-1], "b--", label="Precision")
    plt.plot(thresholds, recalls[:-1], "g-", label="Recall")
    plt.plot(thresholds, acc, "r-", label="Accuracy")
    plt.plot(thresholds, precisions[:-1], "o", color = 'blue')
    plt.plot(thresholds, recalls[:-1], "o", color = 'green')
    plt.plot(thresholds, acc, "o", color = 'red')
    plt.ylabel("Score")
    plt.xlabel("Decision Threshold")
    plt.legend(loc='best')
    plt.legend()
plot_precision_recall_vs_threshold(p, r, thresholds)
